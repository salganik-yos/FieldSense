# %%
import sys
import os

if os.path.exists('C:/Users/after/FieldSense/core/scientific_packages/pynncml'):
    print("Import PyNNCML From Code")
    import sys, os
    FIELDSENSE_ROOT = r"C:\Users\after\FieldSense"  
    if FIELDSENSE_ROOT not in sys.path:
        sys.path.insert(0, FIELDSENSE_ROOT)
else:
    print("Install PyNNCML From pip")
    # %pip install pynncml

import numpy as np
import inspect
import pynncml as pnc  # type: ignore
print("pynncml version:", getattr(pnc, "__version__", "unknown"))
import torch
import math
from matplotlib import pyplot as plt
import matplotlib as mpl
from tqdm import tqdm
import scipy
from sklearn import metrics

#  @title Hyper-parameters
batch_size = 16  # @param{type:"integer"}
window_size = 32  # @param{type:"integer"}
rnn_n_features = 128  # @param{type:"integer"}
metadata_n_features = 32  # @param{type:"integer"}
n_layers = 2  # @param{type:"integer"}
lr = 1e-4  # @param{type:"number"}
weight_decay = 1e-4  # @param{type:"number"}
rnn_type = pnc.neural_networks.RNNType.GRU  # RNN Type
n_epochs = 200  # @param{type:"integer"}
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


time_slice = slice("2015-06-01", "2015-07-10")  # Time Interval

# Check if local OpenMRG dataset exists in FieldSense dataset folder
openmrg_folder = os.path.join("..", "..", "dataset", "open_datasets", "OpenMRG_Sweden")
openmrg_cml_nc = os.path.join(openmrg_folder, "cml", "cml_metadata.csv")

# PyNNCML's default location (where it downloads/looks for data)
pynncml_default_location = os.path.abspath(os.path.join(".", "data", "OpenMRG.zip"))

if os.path.exists(openmrg_folder):
    print(f"✓ OpenMRG_Sweden folder found at: {os.path.abspath(openmrg_folder)}")
    if os.path.exists(openmrg_cml_nc):
        print(f"✓ Data file (cml.nc) found in local dataset folder")
        print(f"  Note: PyNNCML uses its default location: {pynncml_default_location}")
        print(f"  The local dataset at {os.path.abspath(openmrg_folder)} will not be used automatically")
    else:
        print(f"⚠ Data file (cml.nc) NOT found in: {os.path.abspath(openmrg_cml_nc)}")
        print(f"  PyNNCML will use/download data from: {pynncml_default_location}")
else:
    print(f"⚠ OpenMRG_Sweden folder not found at: {os.path.abspath(openmrg_folder)}")
    print(f"  PyNNCML will use/download data from: {pynncml_default_location}")

dataset = pnc.datasets.loader_open_mrg_dataset(time_slice=time_slice)
print(inspect.signature(pnc.datasets.loader_open_mrg_dataset))

#plot links and gages

dataset.link_set.plot_links(scale=True, scale_factor=1.0)
plt.grid()
plt.tick_params(left=False, right=False, labelleft=False, labelbottom=False, bottom=False)
plt.show()
# Out:
# Install PyNNCML From pip
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pynncml in c:\users\after\appdata\roaming\python\python311\site-packages (0.3.7)
# Requirement already satisfied: numpy in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (2.3.5)
# Requirement already satisfied: torch in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (2.9.1)
# Requirement already satisfied: torchvision in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (0.24.1)
# Requirement already satisfied: matplotlib in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (3.10.8)
# Requirement already satisfied: scipy in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (1.16.3)
# Requirement already satisfied: pandas in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (2.3.3)
# Requirement already satisfied: xarray in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (2025.12.0)
# Requirement already satisfied: utm in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (0.8.1)
# Requirement already satisfied: netcdf4 in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (1.7.3)
# Requirement already satisfied: tqdm in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (4.67.1)
# Requirement already satisfied: prettytable in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (3.17.0)
# Requirement already satisfied: huggingface-hub in c:\users\after\appdata\roaming\python\python311\site-packages (from pynncml) (1.2.3)
# Requirement already satisfied: filelock in c:\users\after\appdata\roaming\python\python311\site-packages (from huggingface-hub->pynncml) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\after\appdata\roaming\python\python311\site-packages (from huggingface-hub->pynncml) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\after\appdata\roaming\python\python311\site-packages (from huggingface-hub->pynncml) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\after\appdata\roaming\python\python311\site-packages (from huggingface-hub->pynncml) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\after\appdata\roaming\python\python311\site-packages (from huggingface-hub->pynncml) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\after\appdata\roaming\python\python311\site-packages (from huggingface-hub->pynncml) (6.0.3)
# Requirement already satisfied: shellingham in c:\users\after\appdata\roaming\python\python311\site-packages (from huggingface-hub->pynncml) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\after\appdata\roaming\python\python311\site-packages (from huggingface-hub->pynncml) (0.21.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\after\appdata\roaming\python\python311\site-packages (from huggingface-hub->pynncml) (4.15.0)
# Requirement already satisfied: anyio in c:\users\after\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub->pynncml) (4.12.0)
# Requirement already satisfied: certifi in c:\users\after\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub->pynncml) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\after\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub->pynncml) (1.0.9)
# Requirement already satisfied: idna in c:\users\after\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub->pynncml) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\after\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->pynncml) (0.16.0)
# Requirement already satisfied: colorama in c:\users\after\appdata\roaming\python\python311\site-packages (from tqdm->pynncml) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\after\appdata\roaming\python\python311\site-packages (from matplotlib->pynncml) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\after\appdata\roaming\python\python311\site-packages (from matplotlib->pynncml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\after\appdata\roaming\python\python311\site-packages (from matplotlib->pynncml) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\after\appdata\roaming\python\python311\site-packages (from matplotlib->pynncml) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\after\appdata\roaming\python\python311\site-packages (from matplotlib->pynncml) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\after\appdata\roaming\python\python311\site-packages (from matplotlib->pynncml) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\after\appdata\roaming\python\python311\site-packages (from matplotlib->pynncml) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\after\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->pynncml) (1.17.0)
# Requirement already satisfied: cftime in c:\users\after\appdata\roaming\python\python311\site-packages (from netcdf4->pynncml) (1.6.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\after\appdata\roaming\python\python311\site-packages (from pandas->pynncml) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\after\appdata\roaming\python\python311\site-packages (from pandas->pynncml) (2025.3)
# Requirement already satisfied: wcwidth in c:\users\after\appdata\roaming\python\python311\site-packages (from prettytable->pynncml) (0.2.14)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\after\appdata\roaming\python\python311\site-packages (from torch->pynncml) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\after\appdata\roaming\python\python311\site-packages (from torch->pynncml) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\after\appdata\roaming\python\python311\site-packages (from torch->pynncml) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\after\appdata\roaming\python\python311\site-packages (from sympy>=1.13.3->torch->pynncml) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\after\appdata\roaming\python\python311\site-packages (from jinja2->torch->pynncml) (3.0.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\after\appdata\roaming\python\python311\site-packages (from typer-slim->huggingface-hub->pynncml) (8.3.1)
# Note: you may need to restart the kernel to use updated packages.
# pynncml version: 0.3.7
# ✓ OpenMRG_Sweden folder found at: C:\Users\after\FieldSense\dataset\open_datasets\OpenMRG_Sweden
# ✓ Data file (cml.nc) found in local dataset folder
#   Note: PyNNCML uses its default location: C:\Users\after\FieldSense\projects\SY_Data_Driven\data\OpenMRG.zip
#   The local dataset at C:\Users\after\FieldSense\dataset\open_datasets\OpenMRG_Sweden will not be used automatically
# File already exists at desired location ./data/OpenMRG.zip
# Not downloading!
# 100%|████████████████████████████████████████████████████████████████████████████████| 728/728 [04:15<00:00,  2.85it/s]
# (data_path='./data/', change2min_max=False, xy_min=None, xy_max=None, time_slice=None, link2gauge_distance=2000, window_size_in_min=15, multiple_gauges_per_link=False, link_selection: pynncml.datasets.xarray_processing.LinkSelection = <LinkSelection.GAUGEONLY: 1>)

# %%
# compute Rain Statistics
rg = np.stack([p.data_array for p in dataset.point_set]).flatten()
param = scipy.stats.expon.fit(rg)
exp_gamma = param[1]
print("Rain Rate Statistics")
print("Mean[mm/hr]:", np.mean(rg))
print("Std[mm/hr]:", np.std(rg))
print("Parentage of wet samples", 100 * np.sum(rg > 0) / rg.size)
print("Parentage of dry samples", 100 * np.sum(rg == 0) / rg.size)
print("Exponential Distribution Parameters:", param)
_ = plt.hist(rg, bins=100, density=True)
plt.plot(np.linspace(0, np.max(rg), 100), scipy.stats.expon.pdf(np.linspace(0, np.max(rg), 100), *param))
plt.grid()
plt.xlabel("Rain Rate[mm/hr]")
plt.ylabel("Density")
plt.tight_layout()
plt.show()
# Out:
# Rain Rate Statistics
# Mean[mm/hr]: 0.10113861569949811
# Std[mm/hr]: 0.6187717133949918
# Parentage of wet samples 8.323200741126744
# Parentage of dry samples 91.67679925887326
# Exponential Distribution Parameters: (0.0, 0.10113861569949811)

# %%
n_epochs = 200  # @param{type:"integer"}
rnn_n_features = 256  # @param{type:"integer"}
training_dataset, validation_dataset = torch.utils.data.random_split(dataset, [0.8, 0.2])
data_loader = torch.utils.data.DataLoader(training_dataset, batch_size)
val_loader = torch.utils.data.DataLoader(validation_dataset, batch_size)
model = pnc.scm.rain_estimation.two_step_network(n_layers=n_layers,  # Number of RNN layers
                                                 rnn_type=rnn_type,  # Type of RNN (GRU, LSTM)
                                                 normalization_cfg=pnc.training_helpers.compute_data_normalization(
                                                     data_loader),
                                                 # Compute the normalization statistics from the training dataset.
                                                 rnn_input_size=180,  # 90 + 90 (RSL + TSL)
                                                 rnn_n_features=rnn_n_features,  # Number of features in the RNN
                                                 metadata_input_size=2,  # Number of metadata features
                                                 metadata_n_features=metadata_n_features,
                                                 # Number of features in the metadata
                                                 pretrained=False).to(
    device)  # Pretrained model is set to False to train the model from scratch.

class RegressionLoss(torch.nn.Module):
    def __init__(self, in_gamma, gamma_s=0.9):
        super(RegressionLoss, self).__init__()
        self.in_gamma = in_gamma
        self.gamma_s = gamma_s

    def forward(self, input, target):
        delta = (target - input) ** 2
        w = 1 - self.gamma_s * torch.exp(-self.in_gamma * target)
        return torch.sum(torch.mean(w * delta, dim=0))


loss_function_rain_est = RegressionLoss(exp_gamma)
loss_function_wet_dry = torch.nn.BCELoss()

# Find lambda values such that at initialization both loss will be equal:
loss_est = 0
loss_detection = 0
with torch.no_grad():
    for rain_rate, rsl, tsl, metadata in data_loader:
        state = model.init_state(batch_size=rsl.shape[0])
        m_step = (math.floor(rain_rate.shape[1] / window_size))-1
        for step in range(m_step):
            _rr_future = rain_rate[:, step * window_size + 1:(step + 1) * window_size + 1,0].float().to(device)
            _rsl = rsl[:, step * window_size:(step + 1) * window_size, :].to(device)
            _tsl = tsl[:, step * window_size:(step + 1) * window_size, :].to(device)
            rain_estimation_detection, state = model(torch.cat([_rsl, _tsl], dim=-1), metadata.to(device),
                                                     state.detach())
            rain_hat = rain_estimation_detection[:, :, 0]
            rain_detection = rain_estimation_detection[:, :, 1]
            loss_est += loss_function_rain_est(rain_hat, _rr_future)
            loss_detection += loss_function_wet_dry(rain_detection, (_rr_future > 0.1).float())
lambda_value = loss_detection / loss_est

# %%
# Check if trained model exists and load it
model_path = os.path.abspath("forecast_ws32_lr0.0001_rnn256.pth")

# ALWAYS declare am so later cells can use it
am = pnc.metrics.AverageMetric()

if os.path.exists(model_path):
    print(f"Loading trained model from {model_path}")
    ckpt = torch.load(model_path, map_location=device, weights_only=False)

    # Backward-compatible: allow older files that saved only state_dict
    if isinstance(ckpt, dict) and "model_state_dict" in ckpt:
        model.load_state_dict(ckpt["model_state_dict"])

        # Recreate ra so the plotting cell works after loading
        ra = pnc.metrics.ResultsAccumulator()
        loss_hist = ckpt.get("loss_history", {})
        for l, le, ld in zip(
            loss_hist.get("loss", []),
            loss_hist.get("loss_est", []),
            loss_hist.get("loss_detection", []),
        ):
            ra.add_results(loss=l, loss_est=le, loss_detection=ld)

        # Optional: restore last-epoch snapshot into am (for inspection only)
        am_snapshot = ckpt.get("am_snapshot", None)
        if am_snapshot is not None:
            last = am_snapshot.get("last_epoch", {})
            am.clear()
            if last:
                am.add_results(
                    loss=last.get("loss", 0.0),
                    loss_est=last.get("loss_est", 0.0),
                    loss_detection=last.get("loss_detection", 0.0),
                )

    else:
        # Older weights-only file
        model.load_state_dict(ckpt)
        ra = pnc.metrics.ResultsAccumulator()
        am.clear()

    print(f"Loaded trained model from {model_path}")
    model.eval()  # Set to evaluation mode
    print("Model loaded. Skipping training.")

else:
    print(f"Model file not found at {model_path}. Starting training...")

    opt = torch.optim.RAdam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ra = pnc.metrics.ResultsAccumulator()
    am = pnc.metrics.AverageMetric()  # already declared, but explicit here is fine

    model.train()
    print("Start Training")

    for epoch in tqdm(range(n_epochs)):
        am.clear()

        for rain_rate, rsl, tsl, metadata in data_loader:
            state = model.init_state(batch_size=rsl.shape[0])
            m_step = math.floor(rain_rate.shape[1] / window_size)

            for step in range(m_step):
                opt.zero_grad()

                _rr_future = rain_rate[
                    :, step * window_size+1 : (step + 1) * window_size+1, 0
                ].float().to(device)
                _rsl = rsl[
                    :, step * window_size : (step + 1) * window_size, :
                ].to(device)
                _tsl = tsl[
                    :, step * window_size : (step + 1) * window_size, :
                ].to(device)

                rain_estimation_detection, state = model(
                    torch.cat([_rsl, _tsl], dim=-1),
                    metadata.to(device),
                    state.detach(),
                )

                rain_hat = rain_estimation_detection[:, :, 0]
                rain_detection = rain_estimation_detection[:, :, 1]

                loss_est = loss_function_rain_est(rain_hat, _rr_future)
                loss_detection = loss_function_wet_dry(
                    rain_detection, (_rr_future > 0.1).float()
                )
                loss = lambda_value * loss_est + loss_detection

                loss.backward()
                opt.step()

                am.add_results(
                    loss=loss.item(),
                    loss_est=loss_est.item(),
                    loss_detection=loss_detection.item(),
                )

        ra.add_results(
            loss=am.get_results("loss"),
            loss_est=am.get_results("loss_est"),
            loss_detection=am.get_results("loss_detection"),
        )

    # ---- Save checkpoint ----
    loss_history = {
        "loss": list(ra.get_results("loss")),
        "loss_est": list(ra.get_results("loss_est")),
        "loss_detection": list(ra.get_results("loss_detection")),
    }

    am_snapshot = {
        "last_epoch": {
            "loss": am.get_results("loss"),
            "loss_est": am.get_results("loss_est"),
            "loss_detection": am.get_results("loss_detection"),
        }
    }

    ckpt = {
        "model_state_dict": model.state_dict(),
        "loss_history": loss_history,
        "am_snapshot": am_snapshot,
        "hyperparams": {
            "lr": lr,
            "weight_decay": weight_decay,
            "lambda_value": lambda_value,
            "window_size": window_size,
            "n_epochs": n_epochs,
        },
    }

    torch.save(ckpt, model_path)
    print("Model saved successfully!")
# Out:
# Loading trained model from C:\Users\after\FieldSense\projects\SY_Data_Driven\forecast_ws32_lr0.0001_rnn256.pth
# Loaded trained model from C:\Users\after\FieldSense\projects\SY_Data_Driven\forecast_ws32_lr0.0001_rnn256.pth
# Model loaded. Skipping training.

# %%
plt.plot(ra.get_results("loss"), label="Total Loss")
plt.plot(ra.get_results("loss_est"), label="Rain Rate Loss")
plt.plot(ra.get_results("loss_detection"), label="Wet/Dry Loss")
plt.grid()
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
model.eval()
ga = pnc.metrics.GroupAnalysis()

# NEW: collectors across ALL batches (בלי לשנות את ההתנהגות המקורית)
_all_rain_ref_list = []
_all_rain_hat_list = []
_all_rain_persist_list = []
_all_detection_list = []

with torch.no_grad():
    for rain_rate, rsl, tsl, metadata in val_loader:
        state = model.init_state(batch_size=rsl.shape[0])
        m_step = (math.floor(rain_rate.shape[1] / window_size)) - 1
        am.clear()

        # ORIGINAL (נשאר בדיוק כמו אצלך)
        rain_ref_list = []
        rain_hat_list = []
        detection_list = []

        # NEW: persistence list for THIS batch (לא מפריע לפלט המקורי)
        rain_persist_list = []

        for step in range(m_step):
            _rr_future = rain_rate[:, step * window_size + 1:(step + 1) * window_size + 1, 0].float().to(device)

            # NEW: persistence baseline aligned to the same horizon
            _rr_persist = rain_rate[:, step * window_size:(step + 1) * window_size, 0].float().to(device)

            _rsl = rsl[:, step * window_size:(step + 1) * window_size, :].to(device)
            _tsl = tsl[:, step * window_size:(step + 1) * window_size, :].to(device)

            rain_estimation_detection, state = model(
                torch.cat([_rsl, _tsl], dim=-1),
                metadata.to(device),
                state.detach()
            )

            rain_detection = rain_estimation_detection[:, :, 1]
            rain_hat = rain_estimation_detection[:, :, 0] * torch.round(
                rain_detection
            )  # Rain Rate is computed only for wet samples

            # ORIGINAL
            rain_hat_list.append(rain_hat.detach().cpu().numpy())
            rain_ref_list.append(_rr_future.detach().cpu().numpy())
            ga.append(rain_ref_list[-1], rain_hat_list[-1])
            detection_list.append(torch.round(rain_detection).detach().cpu().numpy())

            delta = rain_hat.squeeze(dim=-1) - _rr_future
            bias = torch.mean(delta)
            mse = torch.mean(delta ** 2)
            am.add_results(bias=bias.item(), mse=mse.item())

            # NEW
            rain_persist_list.append(_rr_persist.detach().cpu().numpy())

        # NEW: aggregate across all batches
        _all_rain_ref_list.extend(rain_ref_list)
        _all_rain_hat_list.extend(rain_hat_list)
        _all_rain_persist_list.extend(rain_persist_list)
        _all_detection_list.extend(detection_list)

# =========================
# ORIGINAL OUTPUTS (unchanged)
# =========================
actual = np.concatenate(detection_list).flatten()
predicted = (np.concatenate(rain_ref_list) > 0.1).astype("float").flatten()
confusion_matrix = metrics.confusion_matrix(actual, predicted)
max_rain = np.max(np.concatenate(rain_ref_list))
g_array = np.linspace(0, max_rain, 6)

print("Results Detection:")
print("Validation Results of Two-Step RNN")
print("Accuracy[%]:", 100 * (np.sum(actual == predicted) / actual.size))
print("F1 Score:", metrics.f1_score(actual, predicted))

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[0, 1])
cm_display.plot()
plt.show()

print("Results Estimation:")
_ = ga.run_analysis(np.stack([g_array[:-1], g_array[1:]], axis=-1))

# =========================
# NEW OUTPUT: NSS (added)
# =========================
# Compute NSS over ALL validation batches (more meaningful)
ref_all = np.concatenate(_all_rain_ref_list).reshape(-1)
hat_all = np.concatenate(_all_rain_hat_list).reshape(-1)
persist_all = np.concatenate(_all_rain_persist_list).reshape(-1)

rmse_model_all = np.sqrt(np.mean((hat_all - ref_all) ** 2))
rmse_persist_all = np.sqrt(np.mean((persist_all - ref_all) ** 2))
nss_total_all = np.nan if rmse_persist_all == 0 else 1.0 - (rmse_model_all / rmse_persist_all)

print("\nResults Skill (NSS vs Persistence):")
print("Total NSS:", nss_total_all)

print("\nNSS per bin (same bin edges used in the table):")
for i in range(len(g_array) - 1):
    lo, hi = g_array[i], g_array[i + 1]
    mask = (ref_all >= lo) & (ref_all < hi)

    if np.sum(mask) == 0:
        print(f"{lo:.2f} < r < {hi:.2f}: NSS = NaN (no samples)")
        continue

    rmse_m = np.sqrt(np.mean((hat_all[mask] - ref_all[mask]) ** 2))
    rmse_b = np.sqrt(np.mean((persist_all[mask] - ref_all[mask]) ** 2))
    nss_bin = np.nan if rmse_b == 0 else 1.0 - (rmse_m / rmse_b)

    print(f"{lo:.2f} < r < {hi:.2f}: NSS = {nss_bin:.4f}")
# Out:
# Results Detection:
# Validation Results of Two-Step RNN
# Accuracy[%]: 95.88718220338983
# F1 Score: 0.6721553725986912
# Results Estimation:
# -------------------------------------------------- Results Summery --------------------------------------------------
# +--------------+--------------------------+----------------------------------------+----------------------------------------+-----------------------------------------+-----------------------------------------+
# |    Metric    | 0.0<r<3.9000000953674316 | 3.9000000953674316<r<7.809999942779541 | 7.809999942779541<r<11.710000038146973 | 11.710000038146973<r<15.619999885559082 | 15.619999885559082<r<19.520000457763672 |
# +--------------+--------------------------+----------------------------------------+----------------------------------------+-----------------------------------------+-----------------------------------------+
# |     RMSE     |           0.31           |                  1.93                  |                  4.11                  |                   7.12                  |                   4.2                   |
# |     BIAS     |          -0.01           |                  0.54                  |                  3.02                  |                   6.0                   |                   3.63                  |
# |    NRMSE     |           5.07           |                  0.37                  |                  0.45                  |                   0.54                  |                   0.22                  |
# |    NBIAS     |          -0.21           |                  0.1                   |                  0.33                  |                   0.46                  |                   0.19                  |
# | Total Metric |          Value           |                   -                    |                   -                    |                    -                    |                    -                    |
# |     RMSE     |           0.36           |                   -                    |                   -                    |                    -                    |                    -                    |
# |     BIAS     |          -0.01           |                   -                    |                   -                    |                    -                    |                    -                    |
# |    NRMSE     |           3.72           |                   -                    |                   -                    |                    -                    |                    -                    |
# |    NBIAS     |           -0.1           |                   -                    |                   -                    |                    -                    |                    -                    |
# +--------------+--------------------------+----------------------------------------+----------------------------------------+-----------------------------------------+-----------------------------------------+
# ------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Results Skill (NSS vs Persistence):
# Total NSS: 0.14713472
#
# NSS per bin (same bin edges used in the table):
# 0.00 < r < 3.90: NSS = 0.0575
# 3.90 < r < 7.81: NSS = 0.2057
# 7.81 < r < 11.71: NSS = 0.2870
# 11.71 < r < 15.62: NSS = 0.3064
# 15.62 < r < 19.52: NSS = 0.6561

# %%
detection_array = np.concatenate(detection_list, axis=1)
rain_ref_array = np.concatenate(rain_ref_list, axis=1)
detection_array = np.round(detection_array)

rain_array = rain_ref_array[0, :300]
detection_array = detection_array[0, :300]
fig, ax = plt.subplots()
x = np.arange(rain_array.shape[0])
ax.plot(x, rain_array, label="Rain")
rain_max = np.max(rain_array)
ax.fill_between(x, rain_max, where=np.logical_or(np.logical_and(detection_array == 1, rain_array > 0),
                                                 np.logical_and(detection_array == 0, rain_array == 0)),
                facecolor='green', alpha=.5, label="Detection")
ax.fill_between(x, rain_max, where=np.logical_and(detection_array == 0, rain_array > 0), facecolor='red',
                alpha=.5, label="Mis-Detection")
ax.fill_between(x, rain_max, where=np.logical_and(detection_array == 1, rain_array <=0.1), facecolor='white',
                alpha=.5, label="False Alarm")
plt.legend()
plt.ylabel("Rain Rate [mm/hr]")
plt.xlabel("Sample Index")
plt.grid()
plt.show()

# %%
rain_hat_array = np.concatenate(rain_hat_list, axis=1)
rain_ref_array = np.concatenate(rain_ref_list, axis=1)

plt.plot(np.cumsum(np.maximum(rain_hat_array[0, :], 0)), label="Two-Steps RNN")
plt.plot(np.cumsum(rain_ref_array[0, :]), "--", label="Reference")
plt.grid()
plt.legend()
plt.ylabel("Accumulated Rain-Rate[mm]")
plt.xlabel("# Samples")
plt.show()

# %%
import torch
import math
import copy
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pynncml as pnc

# 1. איסוף תחזיות (ללא שינוי)
all_link_preds = []
model.eval()

print("Aggregating predictions for mapping...")
with torch.no_grad():
    for rain_rate, rsl, tsl, metadata in data_loader:
        state = model.init_state(batch_size=rsl.shape[0])
        m_step = math.floor(rain_rate.shape[1] / window_size)
        
        batch_time_preds = []
        for step in range(m_step):
            _rsl = rsl[:, step * window_size:(step + 1) * window_size, :].to(device)
            _tsl = tsl[:, step * window_size:(step + 1) * window_size, :].to(device)
            
            rain_estimation_detection, state = model(
                torch.cat([_rsl, _tsl], dim=-1), 
                metadata.to(device), 
                state.detach()
            )
            
            rain_hat = rain_estimation_detection[:, :, 0]
            rain_detection = rain_estimation_detection[:, :, 1]
            rain_hat = rain_hat * torch.round(rain_detection)
            
            batch_time_preds.append(rain_hat.cpu())
        
        if batch_time_preds:
            link_batch_full_time = torch.cat(batch_time_preds, dim=1)
            all_link_preds.append(link_batch_full_time)

if all_link_preds:
    # --- תיקון מס' 1: ניקוי NaNs מהפלט הגולמי של המודל ---
    res_ml = torch.cat(all_link_preds, dim=0)
    # החלפת כל ה-NaN באפסים (למניעת קריסות בהמשך)
    res_ml = torch.nan_to_num(res_ml, nan=0.0, posinf=0.0, neginf=0.0)
    
    print(f"Predictions shape: {res_ml.shape}") 

    # ---------------------------------------------------------
    # יצירת LinkSet (כמו קודם)
    # ---------------------------------------------------------
    full_dataset = data_loader.dataset.dataset if hasattr(data_loader.dataset, 'dataset') else data_loader.dataset
    if hasattr(full_dataset.link_set, 'link_list'):
        full_link_list = full_dataset.link_set.link_list
    else:
        full_link_list = list(full_dataset.link_set)

    if hasattr(data_loader.dataset, 'indices'):
        indices = data_loader.dataset.indices
        current_link_list = [full_link_list[i] for i in indices]
    else:
        current_link_list = full_link_list[:res_ml.shape[0]]

    LinkSetClass = type(full_dataset.link_set)
    try:
        subset_link_set = LinkSetClass(current_link_list)
    except Exception as e:
        subset_link_set = copy.copy(full_dataset.link_set)
        subset_link_set.link_list = current_link_list

    # ---------------------------------------------------------
    # אינטרפולציה וציור
    # ---------------------------------------------------------
    region_of_interest = 3
    point_per_link = 2
    
    try:
        print("Generating Maps...")
        idw = pnc.mcm.generate_link_set_idw(subset_link_set, roi=region_of_interest)
        rain_map_idw = idw(res_ml).numpy()
        
        gmz = pnc.mcm.generate_link_set_gmz(subset_link_set, roi=region_of_interest, point_per_link=point_per_link)
        rain_map_gmz, losses = gmz(res_ml)
        rain_map_gmz = rain_map_gmz.numpy()
        
        # --- תיקון מס' 2: וידוא שהמפות הסופיות תקינות ---
        rain_map_idw = np.nan_to_num(rain_map_idw, nan=0.0)
        rain_map_gmz = np.nan_to_num(rain_map_gmz, nan=0.0)
        
        # מציאת אינדקס זמן מעניין
        spatial_sum = np.sum(rain_map_gmz, axis=(1, 2))
        index = np.argmax(spatial_sum)
        
        # --- תיקון מס' 3: חישוב בטוח של המקסימום ---
        max_idw = np.max(rain_map_idw[index])
        max_gmz = np.max(rain_map_gmz[index])
        peak_rain = np.max([max_idw, max_gmz])
        
        # אם הכל אפסים או NaN, נקבע ברירת מחדל של 1.0 כדי שהקוד לא יקרוס
        if np.isnan(peak_rain) or peak_rain <= 0.001:
            peak_rain = 1.0
            print("Warning: Peak rain is 0 or NaN, setting scale to 1.0")
        else:
            print(f"Peak rain detected: {peak_rain:.2f} mm/h")
        
        bounds = np.linspace(0, peak_rain, 15)
        norm = mpl.colors.BoundaryNorm(boundaries=bounds, ncolors=256, extend='both')

        fig, ax = plt.subplots(1, 3, figsize=(18, 5))
        
        # IDW
        pc1 = ax[0].pcolormesh(
            idw.x_grid_vector,
            idw.y_grid_vector,
            rain_map_idw[index, :, :].T,
            shading='nearest',
            cmap='turbo',
            norm=norm,
        )
        ax[0].set_title(f'IDW (Time: {index})')
        ax[0].set_aspect('equal')

        # GMZ (שימוש בקואורדינטות של IDW)
        pc2 = ax[1].pcolormesh(
            idw.x_grid_vector,   
            idw.y_grid_vector,   
            rain_map_gmz[index, :, :].T,
            shading='nearest',
            cmap='turbo',
            norm=norm,
        )
        ax[1].set_title(f'GMZ Reconstruction')
        ax[1].set_aspect('equal')

        fig.colorbar(pc2, ax=ax[0:2], label='Rainfall [mm/h]', fraction=0.03, pad=0.04)

        # Loss
        if losses is not None and len(losses.shape) > 1:
            # ניקוי NaNs גם מגרף ה-Loss
            clean_losses = np.nan_to_num(losses[:, index], nan=0.0)
            ax[2].plot(clean_losses, marker='o', markersize=3)
            ax[2].set_title('GMZ Convergence')
            ax[2].grid(True)
        else:
            ax[2].text(0.5, 0.5, "No Loss Data", ha='center')
        
        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"Error: {e}")
        import traceback
        traceback.print_exc()

else:
    print("No predictions were generated.")
# Out:
# Aggregating predictions for mapping...
# Predictions shape: torch.Size([172, 3808])
# Generating Maps...
# Peak rain detected: 7.41 mm/h
# C:\Users\after\AppData\Local\Temp\ipykernel_25592\801014751.py:146: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
